# %% [markdown]
# # 3.4.1 AI Fairness 360
# #### create a version unbiased through these filters

# %% [markdown]
# ## 1) Load Required Libraries

# %%
import aif360
import sys
import numpy as np
from tqdm import tqdm
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from IPython.display import Markdown, display
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2) Load Data

# %%
df = pd.read_csv('./data/train.df.csv')
df.head()
# Out:
#    Unnamed: 0  loan_amnt  term  int_rate  installment grade home_ownership  \
# 0           1       5600  36MO     18.04       202.57     G            OWN
# 1           2       7500  36MO     13.87       255.86     D       MORTGAGE
# 2           3      12200  36MO     12.29       406.91     C            OWN
# 3           4      11200  36MO     11.34       368.48     C           RENT
# 4           5      25000  36MO     15.25       869.70     E       MORTGAGE
#
#    annual_inc verification_status pymnt_plan   ...    gross_operating_surplus  \
# 0    0.667753        NOT_VERIFIED          N   ...                        197
# 1    0.717461        NOT_VERIFIED          N   ...                        197
# 2    0.661276        NOT_VERIFIED          N   ...                        197
# 3    0.667208        NOT_VERIFIED          N   ...                        197
# 4    0.714002            VERIFIED          N   ...                        197
#
# ...

# %% [markdown]
# ## 3) Produce Fairness Evaluations

# %% [markdown]
# Unfortunately there are no _privileged_ or _protected_ attributes in the dataset such as `age`, `education`, `race` and `sex` so bias mitigation cannot be performed.
#
# Although discrimination can and does happen on socio-economic class of which `home_ownership` and `annual_inc` could be proxies, it is incumbent upon any financial institution to provide loans to only those capable of repaying them so discrimination could be easily confounded with sound business decisions. And without other demographic features it is not easy to seperate them.
